# %% [markdown]
# <a href="https://colab.research.google.com/github/avxsharma-glitch/Numerical-optimization/blob/main/NO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Vector: Marks of a student

# %%
import numpy as np

#Vector: Marks of a student
marks = np.array([85, 78, 95, 60])
print("Vector:", marks, "|Shape:", marks.shape)
# Out:
# Vector: [85 78 95 60] |Shape: (4,)

# %%
#Matrix: Marks of multiple students
marks_matrix = np.array([[85, 78, 95],
                        [60, 72, 88],
                        [91, 84, 89]])

print("Matrix:\n", marks_matrix)
print("Shape:", marks_matrix.shape)
# Out:
# Matrix:
#  [[85 78 95]
#  [60 72 88]
#  [91 84 89]]
# Shape: (3, 3)

# %%
# Create a vector which shows Study hours in a week of multiple students in 2d matrix
import numpy as np
study_hours = np.array([[2, 3, 4, 5, 6, 4, 3], [1, 2, 3, 2, 3, 2, 1], [4, 5, 6, 5, 4 , 5, 5]])

# %%
import matplotlib.pyplot as plt

#Line Plot Example
x = np.arange(1, 6) #take range from -10 to 11
y = x**2

plt.plot(x, y, label="y = x^2")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Line Plot Example")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot example
maths = [60, 70, 80, 90, 100]
science = [ 65, 68, 78, 85, 95]

plt.scatter(maths, science)
plt.xlabel("Maths Marks")
plt.ylabel( "Science Marks")
plt.title("Maths vs Science Marks Comparison of students")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Dataset
sizes = np.array([650, 800, 1200, 1500, 2000])
prices = np.array([50,70, 110, 140, 200]) #inlakhs

#plot scatter plot for house size in sq ft and price in lakhs
plt.scatter(sizes, prices, label="data")
plt.xlabel("House Size in sq ft")
plt.ylabel("Price in lakhs")

m, c = 0.1089, -19.97
line = m * sizes + c #hint
plt.plot(sizes, line, color="green", label="Our Hint")
plt.legend()
plt.show()
#Give me values of m and c after hit and trail which makes the line closer to the scatter points

# %%
import numpy as np
import matplotlib.pyplot as plt

#Sample data
x_data = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_data = np.array([2.1, 3.9, 6.2, 7.8, 10.1, 12.3, 14.0, 15.8])

# Create model line (linear fit)
coeffs = np.polyfit(x_data, y_data, 1)
x_line = np.linspace(1, 8, 100)
y_line = coeffs[0] * x_line + coeffs[1]

#Create a plot
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, color='blue', s=80, alpha=0.7, label='Data Points')
plt.plot(x_line, y_line, color='green', linewidth=2, label='Model Line')

#Add Labels and formatting
plt.xlabel('X Values', fontsize=12)
plt.ylabel('Y Values', fontsize=12)
plt.title ('Scatter Plot with Linear Model', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

temperature = np.array([20, 22, 24, 26, 28, 30, 32, 34])
sales = np.array([80, 85, 88, 95, 100, 105, 110, 120])

# Scatter plot
plt.scatter(temperature, sales, label="Data Points")

# Calculate slope (m) and intercept (c)
m, c = np.polyfit(temperature, sales, 1)

# Generate line values
y_line = m * temperature + c

# Plot regression line
plt.plot(temperature, y_line, color='red', label="Best Fit Line")

# Add equation text on plot
equation = f"y = {m:.2f}x + {c:.2f}"
plt.text(min(temperature), max(sales), equation)

plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales")
plt.title("Temperature vs Ice Cream Sales")
plt.legend()
plt.show()
