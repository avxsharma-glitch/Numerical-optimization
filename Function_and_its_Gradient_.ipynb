# %% [markdown]
# <a href="https://colab.research.google.com/github/avxsharma-glitch/Numerical-optimization/blob/main/Function_and_its_Gradient_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and its gradient
def f(x):
  return x**2

def grad(x):
  return 2*x

# Parameters
x = -7 # starting point
learning_rate = 0.05
steps = 20

history = [x]

#Gradient Descent Loop
for i in range(steps):
  slope = grad(x)
  x = x - learning_rate * slope
  history.append(x)

# PLot fuction and steps
x_vals = np.linspace(-10,10,200)
y_vals = f(x_vals)

plt.plot(x_vals, y_vals, label="y=x^2")
plt.scatter(history, [f(i) for i in history], color="red", label="Steps")
plt.legend()
plt.show()

# %%
# try starting points x=10 & x=-7
# try different learning rates 0.01 & 0.5
# what happens when slope is zero

# %%
# take equation f(x) = (x-5)**2 + 3 perform gradient descent

# %%
## Plot multiple lines

x = [ 1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 2, 3, 4, 5]
y3 = [25, 25, 15, 10, 5]

plt.plot(x, y1, label="Model-A")
plt.plot(x, y2, label="Model-B")
plt.plot(x, y3, label="Model-C")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Multiple Models Comparison")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (x-3)**2 + 1

def df_dx(x):
    return 2 * (x-3)

x_start = 0.5
learning_rate = 0.05  # Set learning rate
iterations = 50  # Set the number of iterations

x = x_start
x_history = [x]
y_history = [f(x)]

# Initialize the plot
plt.figure(figsize=(8, 6))

# Create x values for plotting the function curve
x_plot = np.linspace(-1, 6, 100)
y_plot = f(x_plot)
plt.plot(x_plot, y_plot, label=r"$f(x) = (x-3)^2 + 1$", color='blue')

for i in range(iterations):
    gradient = df_dx(x)
    x = x - learning_rate * gradient  # Update x using the gradient
    x_history.append(x)
    y_history.append(f(x))

    print(f"step {i+1}: x = {x:.3f}, f(x) = {f(x):.3f}, gradient: {gradient}")

    # Plot current position of x
    plt.scatter(x, f(x), color='red', zorder=5)
    plt.plot(x_history, y_history, color='green', linestyle='--', alpha=0.5)

# Customize plot appearance
plt.title("Gradient Descent on $f(x) = (x-3)^2 + 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# step 1: x = 0.750, f(x) = 6.062, gradient: -5.0
# step 2: x = 0.975, f(x) = 5.101, gradient: -4.5
# step 3: x = 1.177, f(x) = 4.322, gradient: -4.05
# step 4: x = 1.360, f(x) = 3.690, gradient: -3.645
# step 5: x = 1.524, f(x) = 3.179, gradient: -3.2805
# step 6: x = 1.671, f(x) = 2.765, gradient: -2.95245
# step 7: x = 1.804, f(x) = 2.430, gradient: -2.657205
# step 8: x = 1.924, f(x) = 2.158, gradient: -2.3914845
# step 9: x = 2.031, f(x) = 1.938, gradient: -2.1523360499999997
# step 10: x = 2.128, f(x) = 1.760, gradient: -1.9371024449999998
# step 11: x = 2.215, f(x) = 1.615, gradient: -1.7433922004999998
# step 12: x = 2.294, f(x) = 1.499, gradient: -1.5690529804499995
# step 13: x = 2.365, f(x) = 1.404, gradient: -1.4121476824049992
# step 14: x = 2.428, f(x) = 1.327, gradient: -1.270932914164499
# step 15: x = 2.485, f(x) = 1.265, gradient: -1.1438396227480494
# step 16: x = 2.537, f(x) = 1.215, gradient: -1.0294556604732445
# step 17: x = 2.583, f(x) = 1.174, gradient: -0.9265100944259199
# step 18: x = 2.625, f(x) = 1.141, gradient: -0.8338590849833283
# step 19: x = 2.662, f(x) = 1.114, gradient: -0.750473176484995
# step 20: x = 2.696, f(x) = 1.092, gradient: -0.6754258588364959
# step 21: x = 2.726, f(x) = 1.075, gradient: -0.6078832729528463
# step 22: x = 2.754, f(x) = 1.061, gradient: -0.5470949456575616
# step 23: x = 2.778, f(x) = 1.049, gradient: -0.4923854510918053
# step 24: x = 2.801, f(x) = 1.040, gradient: -0.4431469059826245
# step 25: x = 2.821, f(x) = 1.032, gradient: -0.3988322153843624
# step 26: x = 2.838, f(x) = 1.026, gradient: -0.35894899384592627
# step 27: x = 2.855, f(x) = 1.021, gradient: -0.3230540944613338
# step 28: x = 2.869, f(x) = 1.017, gradient: -0.2907486850152008
# step 29: x = 2.882, f(x) = 1.014, gradient: -0.2616738165136807
# step 30: x = 2.894, f(x) = 1.011, gradient: -0.23550643486231237
# step 31: x = 2.905, f(x) = 1.009, gradient: -0.21195579137608078
# step 32: x = 2.914, f(x) = 1.007, gradient: -0.19076021223847306
# step 33: x = 2.923, f(x) = 1.006, gradient: -0.1716841910146254
# step 34: x = 2.930, f(x) = 1.005, gradient: -0.15451577191316268
# step 35: x = 2.937, f(x) = 1.004, gradient: -0.13906419472184606
# step 36: x = 2.944, f(x) = 1.003, gradient: -0.12515777524966154
# step 37: x = 2.949, f(x) = 1.003, gradient: -0.11264199772469574
# step 38: x = 2.954, f(x) = 1.002, gradient: -0.10137779795222635
# step 39: x = 2.959, f(x) = 1.002, gradient: -0.09124001815700389
# step 40: x = 2.963, f(x) = 1.001, gradient: -0.0821160163413035
# step 41: x = 2.967, f(x) = 1.001, gradient: -0.07390441470717324
# step 42: x = 2.970, f(x) = 1.001, gradient: -0.06651397323645547
# step 43: x = 2.973, f(x) = 1.001, gradient: -0.059862575912809746
# step 44: x = 2.976, f(x) = 1.001, gradient: -0.05387631832152895
# step 45: x = 2.978, f(x) = 1.000, gradient: -0.04848868648937632
# step 46: x = 2.980, f(x) = 1.000, gradient: -0.04363981784043869
# step 47: x = 2.982, f(x) = 1.000, gradient: -0.03927583605639473
# step 48: x = 2.984, f(x) = 1.000, gradient: -0.035348252450755346
# step 49: x = 2.986, f(x) = 1.000, gradient: -0.031813427205680256
# step 50: x = 2.987, f(x) = 1.000, gradient: -0.02863208448511223
